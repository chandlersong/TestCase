# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_excel('scatter_1.xlsx')
plt.plot(data['广告费用x'],data['销售收入y'], 'ro')
plt.ylabel('ad fee')
plt.xlabel('sales income')
plt.show()
